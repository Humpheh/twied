# %%
% pylab inline
figsize(10, 8)

import sys
sys.path.append("/Users/humphreyshotton/ds/twicol")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pymongo import MongoClient
from Polygon import Polygon
from Polygon import Error as PolygonError

from geopy.distance import vincenty

# connect to mongodb
client = MongoClient("localhost", 27017)
db = client["twitter"]

# get the tweet cursor
cursor = db.geotweets.find({'locinf.mi.test': {'$ne': None}})

def get_poly(doc):
    # get the poly
    try:
        poly = eval(doc["locinf"]["mi"]["test"]["poly"])
    except KeyError:
        return None, None
        
    centres = []
    
    p = Polygon()
    for i in poly:
        p.addContour(i)

    try:
        center = p.center()
    except PolygonError:
        return None, None
    
    return p, center

uname = []
infos = []
totalcount = 0
count = 0
nocount = 0

for doc in cursor:
    
    if doc["user"]["screen_name"] == "RiverlevelsUK":
        continue
    
    totalcount += 1
    if doc["geo"] is None:
        continue

    # get the real point
    point = (doc["geo"]["coordinates"][1], doc["geo"]["coordinates"][0])
    # get the poly and the centre
    poly, center = get_poly(doc)
    
    if poly is None:
        nocount += 1
        continue

    distance = vincenty((point[1], point[0]), (center[1], center[0])).km
    
    info = [
        distance,
        poly.area(),
        doc["locinf"]["mi"]["test"]["weight"],
        doc["locinf"]["mi"]["test"]["len"]["polys"],
        doc["locinf"]["mi"]["test"]["len"]["inds"],   
    ]
    uname.append(doc["user"]["screen_name"])
    infos.append(info)
    
    count += 1
    if count % 1000 == 0:
        print("Processed", count)
# Out:
# Processed 1000
# Processed 2000
# Processed 3000
# Processed 4000
# Processed 5000
# Processed 6000
# Processed 7000
# Processed 8000
# Processed 9000
# Processed 10000
# Processed 11000
# Processed 12000
# Processed 13000
# Processed 14000
# Processed 15000
# Processed 16000
# Processed 17000
# Processed 18000
# Processed 19000
# Processed 20000
# Processed 21000
# Processed 22000

# %%
dist = 0
area = 1
weight = 2
polys = 3
inds = 4

X = asarray(infos)
X
# Out:
# array([[  4.94879503e+03,   3.69274187e+00,   2.38272793e+00,
#           6.00000000e+00,   3.00000000e+00],
#        [  2.63795327e+00,   4.70238683e-02,   2.07000000e+00,
#           6.00000000e+00,   3.00000000e+00],
#        [  1.73675015e+03,   3.69274187e+00,   2.38272793e+00,
#           6.00000000e+00,   3.00000000e+00],
#        ...,
#        [  1.81923665e+00,   4.56246914e-02,   1.51000000e+00,
#           6.00000000e+00,   3.00000000e+00],
#        [  2.59111998e+00,   4.70238683e-02,   2.07000000e+00,
#           6.00000000e+00,   2.00000000e+00],
#        [  4.70922355e+00,   4.01925926e-02,   2.17999717e+00,
#           6.00000000e+00,   2.00000000e+00]])

# %%
h = hist(X[:,dist], bins=100)

# %%
fig1 = plt.hist2d(X[:,dist], X[:,weight], bins=40)
b = plt.annotate('test',(0,0))
b

# %%
z = np.polyfit(X[:,weight], X[:,dist], 1)
f = np.poly1d(z)

x_new = np.linspace(0, 6, 100)
y_new = f(x_new)


plot(x_new, y_new)
plot(X[:,weight], X[:,dist], 'b.', alpha=0.05) #

# %%
def func(x, w):
    return sum([x[i+1] * w[i] for i in range(len(w))])
                
def err(x, w):
    return func(x, w) - x[0]

def opt(w):
    return sum([err(x, w) for x in X])

# %%
w = [1, 1, 1, 100]
plot(X[:,0], [func(x, w) for x in X], 'b.')

# %%
import scipy.optimize
   
# use the optimize function
xopt = scipy.optimize.fmin(func=opt, x0=[1, 1, 1, 1])
print("Weights:", xopt)
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# Weights: [ -2.65416005e+50   7.74431616e+48   1.22410502e+49   1.20851611e+50]

# %%
wo = [ -2.65416005e+50, 7.74431616e+48,  1.22410502e+49, 1.20851611e+50]
plot(X[:,0], [func(x, wo) for x in X], 'bo')
